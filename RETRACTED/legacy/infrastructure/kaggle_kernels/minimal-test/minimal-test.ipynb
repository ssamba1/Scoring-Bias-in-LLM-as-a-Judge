# %%
import torch; print(f"CUDA: {torch.cuda.is_available()}, GPU: {torch.cuda.get_device_name(0)}")

# %%
import json; json.dump({"test": True, "gpu": str(torch.cuda.get_device_name(0))}, open("test_output.json", "w"))

# %%
print("Test complete")
